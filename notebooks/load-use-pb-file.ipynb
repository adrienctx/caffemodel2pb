# %% [markdown]
# # First we define a function that, given a pb filename, loads it as a tensorflow graph

# %%
import tensorflow as tf
import numpy as np

def load_graph(frozen_graph_filename):
    # We load the protobuf file from the disk and parse it to retrieve the 
    # unserialized graph_def
    with tf.gfile.GFile(frozen_graph_filename, "rb") as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())

    # Then, we can use again a convenient built-in function to import a graph_def into the 
    # current default Graph
    with tf.Graph().as_default() as graph:
        tf.import_graph_def(
            graph_def, 
            input_map=None, 
            return_elements=None, 
            name="prefix", 
            op_dict=None, 
            producer_op_list=None
        )
    return graph

# %% [markdown]
# # An example of how to load pb files as graphs, and print their ops

# %%
from tensorflow.contrib.quantization import *
# We use our "load_graph" function
# inception_aesthetic = load_graph('../../../aesthetic_learning/inception_model/output_graph.pb')
# small_graph = load_graph('../examples/models/aesthetics_caffenet/aesthetic_classif_quantized.pb')
# full_graph = load_graph('../examples/models/aesthetics_caffenet/frozen_aesthetics_model.pb')
googlenet_graph = load_graph('../examples/models/bvlc_googlenet/frozen_model_googlenet.pb')
# We can verify that we can access the list of operations in the graph
for op in googlenet_graph.get_operations():
    print(op.name)
    # prefix/Placeholder/inputs_placeholder
    # ...
    # prefix/Accuracy/predictions
# Out:
# prefix/Placeholder
# prefix/conv1_7x7_s2/weights
# prefix/conv1_7x7_s2/weights/read
# prefix/conv1_7x7_s2/Conv2D
# prefix/conv1_7x7_s2/biases
# prefix/conv1_7x7_s2/biases/read
# prefix/conv1_7x7_s2/BiasAdd
# prefix/conv1_7x7_s2/conv1_7x7_s2
# prefix/pool1_3x3_s2
# prefix/pool1_norm1
# prefix/conv2_3x3_reduce/weights
# prefix/conv2_3x3_reduce/weights/read
# prefix/conv2_3x3_reduce/Conv2D
# prefix/conv2_3x3_reduce/biases
# prefix/conv2_3x3_reduce/biases/read
# prefix/conv2_3x3_reduce/BiasAdd
# prefix/conv2_3x3_reduce/conv2_3x3_reduce
# prefix/conv2_3x3/weights
# prefix/conv2_3x3/weights/read
# prefix/conv2_3x3/Conv2D
# prefix/conv2_3x3/biases
# prefix/conv2_3x3/biases/read
# prefix/conv2_3x3/BiasAdd
# prefix/conv2_3x3/conv2_3x3
# prefix/conv2_norm2
# prefix/pool2_3x3_s2
# prefix/inception_3a_1x1/weights
# prefix/inception_3a_1x1/weights/read
# prefix/inception_3a_1x1/Conv2D
# prefix/inception_3a_1x1/biases
# prefix/inception_3a_1x1/biases/read
# prefix/inception_3a_1x1/BiasAdd
# prefix/inception_3a_1x1/inception_3a_1x1
# prefix/inception_3a_3x3_reduce/weights
# prefix/inception_3a_3x3_reduce/weights/read
# prefix/inception_3a_3x3_reduce/Conv2D
# prefix/inception_3a_3x3_reduce/biases
# prefix/inception_3a_3x3_reduce/biases/read
# prefix/inception_3a_3x3_reduce/BiasAdd
# prefix/inception_3a_3x3_reduce/inception_3a_3x3_reduce
# prefix/inception_3a_3x3/weights
# prefix/inception_3a_3x3/weights/read
# prefix/inception_3a_3x3/Conv2D
# prefix/inception_3a_3x3/biases
# prefix/inception_3a_3x3/biases/read
# prefix/inception_3a_3x3/BiasAdd
# prefix/inception_3a_3x3/inception_3a_3x3
# prefix/inception_3a_5x5_reduce/weights
# prefix/inception_3a_5x5_reduce/weights/read
# prefix/inception_3a_5x5_reduce/Conv2D
# prefix/inception_3a_5x5_reduce/biases
# prefix/inception_3a_5x5_reduce/biases/read
# prefix/inception_3a_5x5_reduce/BiasAdd
# prefix/inception_3a_5x5_reduce/inception_3a_5x5_reduce
# prefix/inception_3a_5x5/weights
# prefix/inception_3a_5x5/weights/read
# prefix/inception_3a_5x5/Conv2D
# prefix/inception_3a_5x5/biases
# prefix/inception_3a_5x5/biases/read
# prefix/inception_3a_5x5/BiasAdd
# prefix/inception_3a_5x5/inception_3a_5x5
# prefix/inception_3a_pool
# prefix/inception_3a_pool_proj/weights
# prefix/inception_3a_pool_proj/weights/read
# prefix/inception_3a_pool_proj/Conv2D
# prefix/inception_3a_pool_proj/biases
# prefix/inception_3a_pool_proj/biases/read
# prefix/inception_3a_pool_proj/BiasAdd
# prefix/inception_3a_pool_proj/inception_3a_pool_proj
# prefix/inception_3a_output/concat_dim
# prefix/inception_3a_output
# prefix/inception_3b_1x1/weights
# prefix/inception_3b_1x1/weights/read
# prefix/inception_3b_1x1/Conv2D
# prefix/inception_3b_1x1/biases
# prefix/inception_3b_1x1/biases/read
# prefix/inception_3b_1x1/BiasAdd
# prefix/inception_3b_1x1/inception_3b_1x1
# prefix/inception_3b_3x3_reduce/weights
# prefix/inception_3b_3x3_reduce/weights/read
# prefix/inception_3b_3x3_reduce/Conv2D
# prefix/inception_3b_3x3_reduce/biases
# prefix/inception_3b_3x3_reduce/biases/read
# prefix/inception_3b_3x3_reduce/BiasAdd
# prefix/inception_3b_3x3_reduce/inception_3b_3x3_reduce
# prefix/inception_3b_3x3/weights
# prefix/inception_3b_3x3/weights/read
# prefix/inception_3b_3x3/Conv2D
# prefix/inception_3b_3x3/biases
# prefix/inception_3b_3x3/biases/read
# prefix/inception_3b_3x3/BiasAdd
# prefix/inception_3b_3x3/inception_3b_3x3
# prefix/inception_3b_5x5_reduce/weights
# prefix/inception_3b_5x5_reduce/weights/read
# prefix/inception_3b_5x5_reduce/Conv2D
# prefix/inception_3b_5x5_reduce/biases
# prefix/inception_3b_5x5_reduce/biases/read
# prefix/inception_3b_5x5_reduce/BiasAdd
# prefix/inception_3b_5x5_reduce/inception_3b_5x5_reduce
# prefix/inception_3b_5x5/weights
# prefix/inception_3b_5x5/weights/read
# prefix/inception_3b_5x5/Conv2D
# prefix/inception_3b_5x5/biases
# prefix/inception_3b_5x5/biases/read
# prefix/inception_3b_5x5/BiasAdd
# prefix/inception_3b_5x5/inception_3b_5x5
# prefix/inception_3b_pool
# prefix/inception_3b_pool_proj/weights
# prefix/inception_3b_pool_proj/weights/read
# prefix/inception_3b_pool_proj/Conv2D
# prefix/inception_3b_pool_proj/biases
# prefix/inception_3b_pool_proj/biases/read
# prefix/inception_3b_pool_proj/BiasAdd
# prefix/inception_3b_pool_proj/inception_3b_pool_proj
# prefix/inception_3b_output/concat_dim
# prefix/inception_3b_output
# prefix/pool3_3x3_s2
# prefix/inception_4a_1x1/weights
# prefix/inception_4a_1x1/weights/read
# prefix/inception_4a_1x1/Conv2D
# prefix/inception_4a_1x1/biases
# prefix/inception_4a_1x1/biases/read
# prefix/inception_4a_1x1/BiasAdd
# prefix/inception_4a_1x1/inception_4a_1x1
# prefix/inception_4a_3x3_reduce/weights
# prefix/inception_4a_3x3_reduce/weights/read
# prefix/inception_4a_3x3_reduce/Conv2D
# prefix/inception_4a_3x3_reduce/biases
# prefix/inception_4a_3x3_reduce/biases/read
# prefix/inception_4a_3x3_reduce/BiasAdd
# prefix/inception_4a_3x3_reduce/inception_4a_3x3_reduce
# prefix/inception_4a_3x3/weights
# prefix/inception_4a_3x3/weights/read
# prefix/inception_4a_3x3/Conv2D
# prefix/inception_4a_3x3/biases
# prefix/inception_4a_3x3/biases/read
# prefix/inception_4a_3x3/BiasAdd
# prefix/inception_4a_3x3/inception_4a_3x3
# prefix/inception_4a_5x5_reduce/weights
# prefix/inception_4a_5x5_reduce/weights/read
# prefix/inception_4a_5x5_reduce/Conv2D
# prefix/inception_4a_5x5_reduce/biases
# prefix/inception_4a_5x5_reduce/biases/read
# prefix/inception_4a_5x5_reduce/BiasAdd
# prefix/inception_4a_5x5_reduce/inception_4a_5x5_reduce
# prefix/inception_4a_5x5/weights
# prefix/inception_4a_5x5/weights/read
# prefix/inception_4a_5x5/Conv2D
# prefix/inception_4a_5x5/biases
# prefix/inception_4a_5x5/biases/read
# prefix/inception_4a_5x5/BiasAdd
# prefix/inception_4a_5x5/inception_4a_5x5
# prefix/inception_4a_pool
# prefix/inception_4a_pool_proj/weights
# prefix/inception_4a_pool_proj/weights/read
# prefix/inception_4a_pool_proj/Conv2D
# prefix/inception_4a_pool_proj/biases
# prefix/inception_4a_pool_proj/biases/read
# prefix/inception_4a_pool_proj/BiasAdd
# prefix/inception_4a_pool_proj/inception_4a_pool_proj
# prefix/inception_4a_output/concat_dim
# prefix/inception_4a_output
# prefix/inception_4b_1x1/weights
# prefix/inception_4b_1x1/weights/read
# prefix/inception_4b_1x1/Conv2D
# prefix/inception_4b_1x1/biases
# prefix/inception_4b_1x1/biases/read
# prefix/inception_4b_1x1/BiasAdd
# prefix/inception_4b_1x1/inception_4b_1x1
# prefix/inception_4b_3x3_reduce/weights
# prefix/inception_4b_3x3_reduce/weights/read
# prefix/inception_4b_3x3_reduce/Conv2D
# prefix/inception_4b_3x3_reduce/biases
# prefix/inception_4b_3x3_reduce/biases/read
# prefix/inception_4b_3x3_reduce/BiasAdd
# prefix/inception_4b_3x3_reduce/inception_4b_3x3_reduce
# prefix/inception_4b_3x3/weights
# prefix/inception_4b_3x3/weights/read
# prefix/inception_4b_3x3/Conv2D
# prefix/inception_4b_3x3/biases
# prefix/inception_4b_3x3/biases/read
# prefix/inception_4b_3x3/BiasAdd
# prefix/inception_4b_3x3/inception_4b_3x3
# prefix/inception_4b_5x5_reduce/weights
# prefix/inception_4b_5x5_reduce/weights/read
# prefix/inception_4b_5x5_reduce/Conv2D
# prefix/inception_4b_5x5_reduce/biases
# prefix/inception_4b_5x5_reduce/biases/read
# prefix/inception_4b_5x5_reduce/BiasAdd
# prefix/inception_4b_5x5_reduce/inception_4b_5x5_reduce
# prefix/inception_4b_5x5/weights
# prefix/inception_4b_5x5/weights/read
# prefix/inception_4b_5x5/Conv2D
# prefix/inception_4b_5x5/biases
# prefix/inception_4b_5x5/biases/read
# prefix/inception_4b_5x5/BiasAdd
# prefix/inception_4b_5x5/inception_4b_5x5
# prefix/inception_4b_pool
# prefix/inception_4b_pool_proj/weights
# prefix/inception_4b_pool_proj/weights/read
# prefix/inception_4b_pool_proj/Conv2D
# prefix/inception_4b_pool_proj/biases
# prefix/inception_4b_pool_proj/biases/read
# prefix/inception_4b_pool_proj/BiasAdd
# prefix/inception_4b_pool_proj/inception_4b_pool_proj
# prefix/inception_4b_output/concat_dim
# prefix/inception_4b_output
# prefix/inception_4c_1x1/weights
# prefix/inception_4c_1x1/weights/read
# prefix/inception_4c_1x1/Conv2D
# prefix/inception_4c_1x1/biases
# prefix/inception_4c_1x1/biases/read
# prefix/inception_4c_1x1/BiasAdd
# prefix/inception_4c_1x1/inception_4c_1x1
# prefix/inception_4c_3x3_reduce/weights
# prefix/inception_4c_3x3_reduce/weights/read
# prefix/inception_4c_3x3_reduce/Conv2D
# prefix/inception_4c_3x3_reduce/biases
# prefix/inception_4c_3x3_reduce/biases/read
# prefix/inception_4c_3x3_reduce/BiasAdd
# prefix/inception_4c_3x3_reduce/inception_4c_3x3_reduce
# prefix/inception_4c_3x3/weights
# prefix/inception_4c_3x3/weights/read
# prefix/inception_4c_3x3/Conv2D
# prefix/inception_4c_3x3/biases
# prefix/inception_4c_3x3/biases/read
# prefix/inception_4c_3x3/BiasAdd
# prefix/inception_4c_3x3/inception_4c_3x3
# prefix/inception_4c_5x5_reduce/weights
# prefix/inception_4c_5x5_reduce/weights/read
# prefix/inception_4c_5x5_reduce/Conv2D
# prefix/inception_4c_5x5_reduce/biases
# prefix/inception_4c_5x5_reduce/biases/read
# prefix/inception_4c_5x5_reduce/BiasAdd
# prefix/inception_4c_5x5_reduce/inception_4c_5x5_reduce
# prefix/inception_4c_5x5/weights
# prefix/inception_4c_5x5/weights/read
# prefix/inception_4c_5x5/Conv2D
# prefix/inception_4c_5x5/biases
# prefix/inception_4c_5x5/biases/read
# prefix/inception_4c_5x5/BiasAdd
# prefix/inception_4c_5x5/inception_4c_5x5
# prefix/inception_4c_pool
# prefix/inception_4c_pool_proj/weights
# prefix/inception_4c_pool_proj/weights/read
# prefix/inception_4c_pool_proj/Conv2D
# prefix/inception_4c_pool_proj/biases
# prefix/inception_4c_pool_proj/biases/read
# prefix/inception_4c_pool_proj/BiasAdd
# prefix/inception_4c_pool_proj/inception_4c_pool_proj
# prefix/inception_4c_output/concat_dim
# prefix/inception_4c_output
# prefix/inception_4d_1x1/weights
# prefix/inception_4d_1x1/weights/read
# prefix/inception_4d_1x1/Conv2D
# prefix/inception_4d_1x1/biases
# prefix/inception_4d_1x1/biases/read
# prefix/inception_4d_1x1/BiasAdd
# prefix/inception_4d_1x1/inception_4d_1x1
# prefix/inception_4d_3x3_reduce/weights
# prefix/inception_4d_3x3_reduce/weights/read
# prefix/inception_4d_3x3_reduce/Conv2D
# prefix/inception_4d_3x3_reduce/biases
# prefix/inception_4d_3x3_reduce/biases/read
# prefix/inception_4d_3x3_reduce/BiasAdd
# prefix/inception_4d_3x3_reduce/inception_4d_3x3_reduce
# prefix/inception_4d_3x3/weights
# prefix/inception_4d_3x3/weights/read
# prefix/inception_4d_3x3/Conv2D
# prefix/inception_4d_3x3/biases
# prefix/inception_4d_3x3/biases/read
# prefix/inception_4d_3x3/BiasAdd
# prefix/inception_4d_3x3/inception_4d_3x3
# prefix/inception_4d_5x5_reduce/weights
# prefix/inception_4d_5x5_reduce/weights/read
# prefix/inception_4d_5x5_reduce/Conv2D
# prefix/inception_4d_5x5_reduce/biases
# prefix/inception_4d_5x5_reduce/biases/read
# prefix/inception_4d_5x5_reduce/BiasAdd
# prefix/inception_4d_5x5_reduce/inception_4d_5x5_reduce
# prefix/inception_4d_5x5/weights
# prefix/inception_4d_5x5/weights/read
# prefix/inception_4d_5x5/Conv2D
# prefix/inception_4d_5x5/biases
# prefix/inception_4d_5x5/biases/read
# prefix/inception_4d_5x5/BiasAdd
# prefix/inception_4d_5x5/inception_4d_5x5
# prefix/inception_4d_pool
# prefix/inception_4d_pool_proj/weights
# prefix/inception_4d_pool_proj/weights/read
# prefix/inception_4d_pool_proj/Conv2D
# prefix/inception_4d_pool_proj/biases
# prefix/inception_4d_pool_proj/biases/read
# prefix/inception_4d_pool_proj/BiasAdd
# prefix/inception_4d_pool_proj/inception_4d_pool_proj
# prefix/inception_4d_output/concat_dim
# prefix/inception_4d_output
# prefix/inception_4e_1x1/weights
# prefix/inception_4e_1x1/weights/read
# prefix/inception_4e_1x1/Conv2D
# prefix/inception_4e_1x1/biases
# prefix/inception_4e_1x1/biases/read
# prefix/inception_4e_1x1/BiasAdd
# prefix/inception_4e_1x1/inception_4e_1x1
# prefix/inception_4e_3x3_reduce/weights
# prefix/inception_4e_3x3_reduce/weights/read
# prefix/inception_4e_3x3_reduce/Conv2D
# prefix/inception_4e_3x3_reduce/biases
# prefix/inception_4e_3x3_reduce/biases/read
# prefix/inception_4e_3x3_reduce/BiasAdd
# prefix/inception_4e_3x3_reduce/inception_4e_3x3_reduce
# prefix/inception_4e_3x3/weights
# prefix/inception_4e_3x3/weights/read
# prefix/inception_4e_3x3/Conv2D
# prefix/inception_4e_3x3/biases
# prefix/inception_4e_3x3/biases/read
# prefix/inception_4e_3x3/BiasAdd
# prefix/inception_4e_3x3/inception_4e_3x3
# prefix/inception_4e_5x5_reduce/weights
# prefix/inception_4e_5x5_reduce/weights/read
# prefix/inception_4e_5x5_reduce/Conv2D
# prefix/inception_4e_5x5_reduce/biases
# prefix/inception_4e_5x5_reduce/biases/read
# prefix/inception_4e_5x5_reduce/BiasAdd
# prefix/inception_4e_5x5_reduce/inception_4e_5x5_reduce
# prefix/inception_4e_5x5/weights
# prefix/inception_4e_5x5/weights/read
# prefix/inception_4e_5x5/Conv2D
# prefix/inception_4e_5x5/biases
# prefix/inception_4e_5x5/biases/read
# prefix/inception_4e_5x5/BiasAdd
# prefix/inception_4e_5x5/inception_4e_5x5
# prefix/inception_4e_pool
# prefix/inception_4e_pool_proj/weights
# prefix/inception_4e_pool_proj/weights/read
# prefix/inception_4e_pool_proj/Conv2D
# prefix/inception_4e_pool_proj/biases
# prefix/inception_4e_pool_proj/biases/read
# prefix/inception_4e_pool_proj/BiasAdd
# prefix/inception_4e_pool_proj/inception_4e_pool_proj
# prefix/inception_4e_output/concat_dim
# prefix/inception_4e_output
# prefix/pool4_3x3_s2
# prefix/inception_5a_1x1/weights
# prefix/inception_5a_1x1/weights/read
# prefix/inception_5a_1x1/Conv2D
# prefix/inception_5a_1x1/biases
# prefix/inception_5a_1x1/biases/read
# prefix/inception_5a_1x1/BiasAdd
# prefix/inception_5a_1x1/inception_5a_1x1
# prefix/inception_5a_3x3_reduce/weights
# prefix/inception_5a_3x3_reduce/weights/read
# prefix/inception_5a_3x3_reduce/Conv2D
# prefix/inception_5a_3x3_reduce/biases
# prefix/inception_5a_3x3_reduce/biases/read
# prefix/inception_5a_3x3_reduce/BiasAdd
# prefix/inception_5a_3x3_reduce/inception_5a_3x3_reduce
# prefix/inception_5a_3x3/weights
# prefix/inception_5a_3x3/weights/read
# prefix/inception_5a_3x3/Conv2D
# prefix/inception_5a_3x3/biases
# prefix/inception_5a_3x3/biases/read
# prefix/inception_5a_3x3/BiasAdd
# prefix/inception_5a_3x3/inception_5a_3x3
# prefix/inception_5a_5x5_reduce/weights
# prefix/inception_5a_5x5_reduce/weights/read
# prefix/inception_5a_5x5_reduce/Conv2D
# prefix/inception_5a_5x5_reduce/biases
# prefix/inception_5a_5x5_reduce/biases/read
# prefix/inception_5a_5x5_reduce/BiasAdd
# prefix/inception_5a_5x5_reduce/inception_5a_5x5_reduce
# prefix/inception_5a_5x5/weights
# prefix/inception_5a_5x5/weights/read
# prefix/inception_5a_5x5/Conv2D
# prefix/inception_5a_5x5/biases
# prefix/inception_5a_5x5/biases/read
# prefix/inception_5a_5x5/BiasAdd
# prefix/inception_5a_5x5/inception_5a_5x5
# prefix/inception_5a_pool
# prefix/inception_5a_pool_proj/weights
# prefix/inception_5a_pool_proj/weights/read
# prefix/inception_5a_pool_proj/Conv2D
# prefix/inception_5a_pool_proj/biases
# prefix/inception_5a_pool_proj/biases/read
# prefix/inception_5a_pool_proj/BiasAdd
# prefix/inception_5a_pool_proj/inception_5a_pool_proj
# prefix/inception_5a_output/concat_dim
# prefix/inception_5a_output
# prefix/inception_5b_1x1/weights
# prefix/inception_5b_1x1/weights/read
# prefix/inception_5b_1x1/Conv2D
# prefix/inception_5b_1x1/biases
# prefix/inception_5b_1x1/biases/read
# prefix/inception_5b_1x1/BiasAdd
# prefix/inception_5b_1x1/inception_5b_1x1
# prefix/inception_5b_3x3_reduce/weights
# prefix/inception_5b_3x3_reduce/weights/read
# prefix/inception_5b_3x3_reduce/Conv2D
# prefix/inception_5b_3x3_reduce/biases
# prefix/inception_5b_3x3_reduce/biases/read
# prefix/inception_5b_3x3_reduce/BiasAdd
# prefix/inception_5b_3x3_reduce/inception_5b_3x3_reduce
# prefix/inception_5b_3x3/weights
# prefix/inception_5b_3x3/weights/read
# prefix/inception_5b_3x3/Conv2D
# prefix/inception_5b_3x3/biases
# prefix/inception_5b_3x3/biases/read
# prefix/inception_5b_3x3/BiasAdd
# prefix/inception_5b_3x3/inception_5b_3x3
# prefix/inception_5b_5x5_reduce/weights
# prefix/inception_5b_5x5_reduce/weights/read
# prefix/inception_5b_5x5_reduce/Conv2D
# prefix/inception_5b_5x5_reduce/biases
# prefix/inception_5b_5x5_reduce/biases/read
# prefix/inception_5b_5x5_reduce/BiasAdd
# prefix/inception_5b_5x5_reduce/inception_5b_5x5_reduce
# prefix/inception_5b_5x5/weights
# prefix/inception_5b_5x5/weights/read
# prefix/inception_5b_5x5/Conv2D
# prefix/inception_5b_5x5/biases
# prefix/inception_5b_5x5/biases/read
# prefix/inception_5b_5x5/BiasAdd
# prefix/inception_5b_5x5/inception_5b_5x5
# prefix/inception_5b_pool
# prefix/inception_5b_pool_proj/weights
# prefix/inception_5b_pool_proj/weights/read
# prefix/inception_5b_pool_proj/Conv2D
# prefix/inception_5b_pool_proj/biases
# prefix/inception_5b_pool_proj/biases/read
# prefix/inception_5b_pool_proj/BiasAdd
# prefix/inception_5b_pool_proj/inception_5b_pool_proj
# prefix/inception_5b_output/concat_dim
# prefix/inception_5b_output
# prefix/pool5_7x7_s1
# prefix/loss3_classifier/Reshape/shape
# prefix/loss3_classifier/Reshape
# prefix/loss3_classifier/weights
# prefix/loss3_classifier/weights/read
# prefix/loss3_classifier/biases
# prefix/loss3_classifier/biases/read
# prefix/loss3_classifier/loss3_classifier/MatMul
# prefix/loss3_classifier/loss3_classifier
# prefix/prob

# %% [markdown]
# # An important step: we need to make sure the image we test on has the right format, matching the graph input layer

# %%
from scipy import misc
image_np = misc.imread('grace_hopper.jpg')
image_resized = misc.imresize(image_np,(224,224,3))
expanded = np.expand_dims(image_resized,axis=0)
duplicated = np.repeat(expanded,32, axis=0)

# %% [markdown]
# # Now we can fill the input tensor with the image, and print out the output (often a vector of probabilities)

# %%
import numpy as np
# We access the input and output nodes 
x_small = googlenet_graph.get_tensor_by_name('prefix/Placeholder:0')
y_small = googlenet_graph.get_tensor_by_name('prefix/prob:0')

# We launch a Session
with tf.Session(graph=googlenet_graph) as sess:
    # Note: we didn't initialize/restore anything, everything is stored in the graph_def
    y_out = sess.run(y_small, feed_dict={
        x_small: duplicated # small graph
    })
    print(y_out) # [[ False ]] Yay, it works!
    print(y_out.shape)
# Out:
# [[  7.44015722e-07   7.79389552e-07   5.32602371e-06 ...,   1.08753184e-07
#     2.93676317e-06   8.79124946e-06]
#  [  7.44015722e-07   7.79389552e-07   5.32602371e-06 ...,   1.08753184e-07
#     2.93676317e-06   8.79124946e-06]
#  [  7.44015722e-07   7.79389552e-07   5.32602371e-06 ...,   1.08753184e-07
#     2.93676317e-06   8.79124946e-06]
#  ...,
#  [  7.44015722e-07   7.79389552e-07   5.32602371e-06 ...,   1.08753184e-07
#     2.93676317e-06   8.79124946e-06]
#  [  7.44015722e-07   7.79389552e-07   5.32602371e-06 ...,   1.08753184e-07
#     2.93676317e-06   8.79124946e-06]
#  [  7.44015722e-07   7.79389552e-07   5.32602371e-06 ...,   1.08753184e-07
#     2.93676317e-06   8.79124946e-06]]
# (32, 1000)
